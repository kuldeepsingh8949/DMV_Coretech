# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
keyword.kwlist         #list of keywords
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
# 1val = 10 # can't start with numerical number

# %%
# val@ = 16 # can't use special character

# %%
# import = 11 # import is reserved keyword

# %%
val_ = 11 # this is valid

# %%
'''
Comment :
single line comment
multiple line comment
'''
# This is single line comment
# Out:
# '\nComment :\nsingle line comment\nmultiple line comment\n'

# %%
# statement 
p1 =29-38   # single line statement
p1
# Out:
# -9

# %%
# multiple line statement
s1="hello"\
"world"
s1
# Out:
# 'helloworld'

# %%
# Docstring
def square(num):
    '''This function returns square of a number'''     
    return num**2

# %%
square(4)
# Out:
# 16

# %%
square.__doc__  # accessing docstring of function by __doc__ attribute
# Out:
# 'This function returns square of a number'

# %%
def even_odd(num):
    """This function checks whether a number is even or odd"""
    if num%2==0:
        return "Even"
    else:
        return "Odd"

# %%
even_odd(8)
# Out:
# 'Even'

# %%
even_odd(5)
# Out:
# 'Odd'

# %%
even_odd.__doc__
# Out:
# 'This function checks whether a number is even or odd'

# %%
var2=10+5j
type(var2)
# Out:
# complex

# %%
a=29+5j
sys.getsizeof(a)
a,"is intance of complex:",isinstance(a,complex)
# Out:
# ((29+5j), 'is intance of complex:', True)

# %%
# size of integer object in bytes
sys.getsizeof(int())
sys.getsizeof(float())
sys.getsizeof(complex())
# Out:
# 32

# %%
# Boolean Type

# %%
# String Type
str1 = "hii" # double quotes
str2 ='hey' # single quotes

# %%
str1
# Out:
# 'hii'

# %%
str2
# Out:
# 'hey'

# %%
str3= ''' this is a multi line string 
i use triple quotes
heyy'''
str3
# Out:
# ' this is a multi line string \ni use triple quotes\nheyy'

# %%
str = "hello "
str*6
# Out:
# 'hello hello hello hello hello hello '

# %%
# string Indexing
# iinn
# 0123
strr = "hello"
strr[4]  # accessing character at index 4
# Out:
# 'o'

# %%
strr[-1]  # accessing last character using negative indexing
# Out:
# 'o'

# %%
strr[len(strr)-1]  # accessing last character using len() function
# Out:
# 'o'

# %%
# strring Slicing
# striing[start:end:step]
strr[1:4]  # slicing from index 1 to 3
# Out:
# 'ell'

# %%
strr[:5]
# Out:
# 'hello'

# %%
strr[-1:5]
# Out:
# 'o'

# %%
# Update and Delete String 
str4 = "hello world"
str4
# Out:
# 'hello world'

# %%
# str4[0:4] = "hii"

# %%
del str4

# %%
str4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[180], line 1
# ----> 1 str4
#
# NameError: name 'str4' is not defined

# %%
s1= "hello"
s2= "world"
s3= s1+s2
s3
# Out:
# 'helloworld'

# %%
# Iterating String
str = "This Is a String"
for i in str:
    print(i)
# Out:
# T
# h
# i
# s
#
# I
# s
#
# a
#
# S
# t
# r
# i
# n
# g

# %%
for i in enumerate(str):
    print(i)
# Out:
# (0, 'T')
# (1, 'h')
# (2, 'i')
# (3, 's')
# (4, ' ')
# (5, 'I')
# (6, 's')
# (7, ' ')
# (8, 'a')
# (9, ' ')
# (10, 'S')
# (11, 't')
# (12, 'r')
# (13, 'i')
# (14, 'n')
# (15, 'g')

# %%
list (enumerate(str))
# Out:
# [(0, 'T'),
#  (1, 'h'),
#  (2, 'i'),
#  (3, 's'),
#  (4, ' '),
#  (5, 'I'),
#  (6, 's'),
#  (7, ' '),
#  (8, 'a'),
#  (9, ' '),
#  (10, 'S'),
#  (11, 't'),
#  (12, 'r'),
#  (13, 'i'),
#  (14, 'n'),
#  (15, 'g')]

# %%
# List 
a= [1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = "Hello bro this is DMV Coretech"
'this'in a #True
# Out:
# True

# %%
str = " Hello bro "
str
# Out:
# ' Hello bro '

# %%
str.strip()
# Out:
# 'Hello bro'

# %%
str.rstrip() # for right side removal
# Out:
# ' Hello bro'

# %%
str.lstrip() # for left side removal
# Out:
# 'Hello bro '

# %%
mystr = "********this **** is DMV******"
mystr
# Out:
# '********this **** is DMV******'

# %%
mystr.strip('*')
# Out:
# 'this **** is DMV'

# %%
mystr2 = "hello hackers"
mystr2
# Out:
# 'hello hackers'

# %%
mystr2.replace('hello','hii')
# Out:
# 'hii hackers'

# %%
mystr3 =" one two three three five two one"
mystr3.count('two')
# Out:
# 2

# %%
mystr3.startswith('two')
# Out:
# False

# %%
mystr3.endswith('one')
# Out:
# True

# %%
list = mystr3.split()
list
# Out:
# ['one', 'two', 'three', 'three', 'five', 'two', 'one']

# %%
# using scape characters
# \t
# \n
# \r
# \b
# \
sttt = " my lang is \"pyhton\" "
sttt
# Out:
# ' my lang is "pyhton" '
