# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
keyword.kwlist         #list of keywords
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
# 1val = 10 # can't start with numerical number
# Out:
#   Cell In[4], line 1
#     1val = 10 # can't start with numerical number
#     ^
# SyntaxError: invalid decimal literal

# %%
# val@ = 16 # can't use special character
# Out:
#   Cell In[8], line 1
#     val@ = 16
#          ^
# SyntaxError: invalid syntax

# %%
# import = 11 # import is reserved keyword
# Out:
#   Cell In[10], line 1
#     import = 11
#            ^
# SyntaxError: invalid syntax

# %%
val_ = 11 # this is valid

# %%
'''
Comment :
single line comment
multiple line comment
'''
# This is single line comment
# Out:
# '\nComment :\nsingle line comment\nmultiple line comment\n'

# %%
# statement 
p1 =29-38   # single line statement
p1
# Out:
# -9

# %%
# multiple line statement
s1="hello"\
"world"
s1
# Out:
# 'helloworld'

# %%
# Docstring
def square(num):
    '''This function returns square of a number'''     
    return num**2

# %%
square(4)
# Out:
# 16

# %%
square.__doc__  # accessing docstring of function by __doc__ attribute
# Out:
# 'This function returns square of a number'

# %%
def even_odd(num):
    """This function checks whether a number is even or odd"""
    if num%2==0:
        return "Even"
    else:
        return "Odd"

# %%
even_odd(8)
# Out:
# 'Even'

# %%
even_odd(5)
# Out:
# 'Odd'

# %%
even_odd.__doc__
# Out:
# 'This function checks whether a number is even or odd'
